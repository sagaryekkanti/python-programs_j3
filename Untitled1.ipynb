# %% [markdown]
# # file handling in python
# 1. file is a collection of information and stored in memory
# 2. files are 2 types '1. text files '2.binary files'
# 3. text files'text, .py, .ipynb, .java ...etc
# 4. binary files .exe, .mp4, .mp3 .apk ...etc

# %%
# file operation 
1. crate files -w mode
2. write files - w mode 
3.read file - r mode
4. append file - a mode

# %%
# write a program to create file using python script
crate_file=open("profile.txt","w")
print("successfully file is crated and verify in home directory")
crate_file.close()
# Out:
# successfully file is crated and verify in home directory

# %%
#write data to file using python script
write_file=open("profile.txt","w")
message="welcome ot tia \n learing pyton programming"
write_file.write(message)
print("successfully write data file, please open profile.txt file")
write_file.close()
# Out:
# successfully write data file, please open profile.txt file
